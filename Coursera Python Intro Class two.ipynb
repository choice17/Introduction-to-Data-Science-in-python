# %% [markdown]
# class two Pandas Series data

# %% [markdown]
# Class two pandas data frame
# >> create data frame
# - pd.Series (string list)
# - pd.Series (number list)
# - pd.Series (nan data)
# >> quesry data frame
# - pd.Series ({index: value})
# - pd.Series ([value1,value2],index=[index1,index2])
# - for loop vs   parallel computing >> np.sum() vs array += int
# - df = pd.DataFrame([ ],index= [ ])
# >> accessing data frame
# - access df by df.loc[index][index] df['index'] df.loc[:,'index'] df.T df.T('index')
# >> manipulating data
# - df.drop('index') df.copy()
# - df['index'] *= 0.8 -= 0.8 += 8 << access value
# >> pd.read_csv(filepath, index_col = 0, skiprows = 1)
# - pd.rename(columns = )
# - df[df['index'] > 0]  #boolean masking
# >> indexing
# - df['country'] = df.index
# - df = df.set_index('Gold') #multi indexing for array bool index access
# - df = df.reset_index()
# - df.loc[ [('Michigan','Washtenaw County'),('Michigan','Wayne County')]]

# %%
import pandas as pd
import numpy as np
pd.Series?

# %%
animals = ['Tiger', 'Bear', 'Moose']
pd.Series(animals)
# Out:
# 0    Tiger
# 1     Bear
# 2    Moose
# dtype: object

# %%
numbers = [1,2,3]
pd.Series(numbers)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
animals = ['Tiger','Bear',None]
pd.Series(animals)
# Out:
# 0    Tiger
# 1     Bear
# 2     None
# dtype: object

# %%
numbers = [1,2,None]
pd.Series(numbers)
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %%
import numpy as np
np.nan ==None
# Out:
# False

# %%
np.nan == np.nan
# Out:
# False

# %%
np.isnan(np.nan)
# Out:
# True

# %%
sports = {'Archery': 'Bhutan',
          'Golf': 'Scotland',
          'Sumo': 'Japan',
          'Taekwondo': 'South Korea'}
s = pd.Series(sports)
s
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# dtype: object

# %%
s.index
# Out:
# Index(['Archery', 'Golf', 'Sumo', 'Taekwondo'], dtype='object')

# %% [markdown]
# sports = {'Archery': 'Bhutan',
#           'Golf': 'Scotland',
#           'Sumo': 'Japan',
#           'Taekwondo': 'South Korea'}
# s = pd.Series(sports)
# s

# %% [markdown]
# # Query a series

# %%
s.iloc[3]
# Out:
# 'South Korea'

# %%
s.loc['Golf']
# Out:
# 'Scotland'

# %%
s[3]
# Out:
# 'South Korea'

# %%
s = pd.Series([100,120.00,101.00,3])

# %%
s
# Out:
# 0    100.0
# 1    120.0
# 2    101.0
# 3      3.0
# dtype: float64

# %%
total = 0
for item in s:
    total += item
print(total)
# Out:
# 324.0

# %%
s.head(1)
# Out:
# 0    100.0
# dtype: float64

# %%
len(s)
# Out:
# 4

# %%
total = np.sum(s)
print(total)
s = pd.Series(np.random.randint(0,1000,10000))
print(s.head(),len(s))
# Out:
# 4957826
# 0    131
# 1    993
# 2    243
# 3     41
# 4     66
# dtype: int32 10000

# %%
# %%timeit -n 100
summary = 0
for item in s:
    summary +=item
# Out:
# 100 loops, best of 3: 1.09 ms per loop

# %%
# %%timeit -n 100
summary = np.sum(s)
# Out:
# 100 loops, best of 3: 138 µs per loop

# %%
s += 2
s.head()
# Out:
# 0    133
# 1    995
# 2    245
# 3     43
# 4     68
# dtype: int32

# %%
s.iteritems()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-365b68f28c12> in <module>()
# ----> 1 s.iteritems().head()
#
# AttributeError: 'zip' object has no attribute 'head'

# %%
for label, value in s.iteritems():
    s.set_value(label,value+2)
s.head()
# Out:
# 0    135
# 1    997
# 2    247
# 3     45
# 4     70
# dtype: int32

# %%
# %%timeit -n 10
s = pd.Series(np.random.randint(0,1000,10000))
for label, value in s.iteritems():
        s.loc[label] = value+2
# Out:
# 10 loops, best of 3: 876 ms per loop

# %%
# %%timeit -n 10
s = pd.Series(np.random.randint(0,1000,10000))
s += 2
# Out:
# 10 loops, best of 3: 259 µs per loop

# %%
s = pd.Series([1,2,3])
s.loc['Animal'] = 'Bears'
s
# Out:
# 0             1
# 1             2
# 2             3
# Animal    Bears
# dtype: object

# %%
original_sports = pd.Series({'Archery': 'Bhutan',
          'Golf': 'Scotland',
          'Sumo': 'Japan',
          'Taekwondo': 'South Korea'})
cricket_loving_countries = pd.Series(['Autralia',
                                      'Barbabon',
                                      'Pakistran',
                                      'England'],
                                     index = ['Cricket',
                                      'Cricket',
                                      'Cricket',
                                      'Cricket'])
all_countries = original_sports.append(cricket_loving_countries)

# %%
original_sports
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# dtype: object

# %%
cricket_loving_countries
# Out:
# Cricket     Autralia
# Cricket     Barbabon
# Cricket    Pakistran
# Cricket      England
# dtype: object

# %%
all_countries
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# Cricket         Autralia
# Cricket         Barbabon
# Cricket        Pakistran
# Cricket          England
# dtype: object

# %% [markdown]
# # The DataFrame Data Structure

# %%
import pandas as pd
purchase_1 = pd.Series({'Name': 'Chris',
                        'Item Purchased': 'Dog Food',
                        'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost': 2.50})
purchase_3 = pd.Series({'Name': 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost': 5.00})
df = pd.DataFrame([purchase_1,purchase_2,purchase_3], index = ['Store 1', 'Store 1','Store 2'])
df.head()
# Out:
#          Cost Item Purchased   Name
# Store 1  22.5       Dog Food  Chris
# Store 1   2.5   Kitty Litter  Kevyn
# Store 2   5.0      Bird Seed  Vinod

# %%
df.loc['Store 2']
# Out:
# Cost                      5
# Item Purchased    Bird Seed
# Name                  Vinod
# Name: Store 2, dtype: object

# %%
type(df.loc['Store 2'])
# Out:
# pandas.core.series.Series

# %%
df['Item Purchased']
# Out:
# Store 1        Dog Food
# Store 1    Kitty Litter
# Store 2       Bird Seed
# Name: Item Purchased, dtype: object

# %%
df.loc['Store 1','Cost' ]
# Out:
# Store 1    22.5
# Store 1     2.5
# Name: Cost, dtype: float64

# %%
df.T
# Out:
#                  Store 1       Store 1    Store 2
# Cost                22.5           2.5          5
# Item Purchased  Dog Food  Kitty Litter  Bird Seed
# Name               Chris         Kevyn      Vinod

# %%
df.T.loc['Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Store 2       5
# Name: Cost, dtype: object

# %%
df['Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Store 2     5.0
# Name: Cost, dtype: float64

# %%
df.loc['Store 1']['Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Name: Cost, dtype: float64

# %%
df.loc[:,['Name','Cost']]
# Out:
#           Name  Cost
# Store 1  Chris  22.5
# Store 1  Kevyn   2.5
# Store 2  Vinod   5.0

# %%
df.drop('Store 1')
# Out:
#          Cost Item Purchased   Name
# Store 2   5.0      Bird Seed  Vinod

# %%
df
# Out:
#          Cost Item Purchased   Name
# Store 1  22.5       Dog Food  Chris
# Store 1   2.5   Kitty Litter  Kevyn
# Store 2   5.0      Bird Seed  Vinod

# %%
copy_df = df.copy()
copy_df = copy_df.drop('Store 1')

# %%
copy_df.drop?

# %%
del copy_df['Name']
copy_df
# Out:
#          Cost Item Purchased
# Store 2   5.0      Bird Seed

# %%
df['Location'] = None
df
# Out:
#          Cost Item Purchased   Name Location
# Store 1  22.5       Dog Food  Chris     None
# Store 1   2.5   Kitty Litter  Kevyn     None
# Store 2   5.0      Bird Seed  Vinod     None

# %%
purchase_1 = pd.Series({'Name': 'Chris',
                        'Item Purchased': 'Dog Food',
                        'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost': 2.50})
purchase_3 = pd.Series({'Name': 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost': 5.00})

df = pd.DataFrame([purchase_1, purchase_2, purchase_3], index=['Store 1', 'Store 1', 'Store 2'])

# %%
df['Cost'] **= 2

# %%
df
# Out:
#                 Cost Item Purchased   Name
# Store 1  1758.887423       Dog Food  Chris
# Store 1     9.016874   Kitty Litter  Kevyn
# Store 2    47.591348      Bird Seed  Vinod

# %% [markdown]
# # data frame indexing and loading

# %%
costs = df['Cost'] #address to a variable
costs
# Out:
# Store 1    1758.887423
# Store 1       9.016874
# Store 2      47.591348
# Name: Cost, dtype: float64

# %%
costs += 2
costs
# Out:
# Store 1    1760.887423
# Store 1      11.016874
# Store 2      49.591348
# Name: Cost, dtype: float64

# %%
df
# Out:
#                 Cost Item Purchased   Name
# Store 1  1760.887423       Dog Food  Chris
# Store 1    11.016874   Kitty Litter  Kevyn
# Store 2    49.591348      Bird Seed  Vinod

# %%
# !cat olympics.csv
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is D0E7-419A
#
#  Directory of C:\Users\takchoi\Desktop\MS\Umdearborn\LectureNote\Machine_Learning\Coursera and stanford UFDLD\Python intro
#
# 13/07/17  02:00 AM    <DIR>          .
# 13/07/17  02:00 AM    <DIR>          ..
# 04/07/17  02:33 AM    <DIR>          .ipynb_checkpoints
# 27/06/17  03:38 PM           250,023 class one note.pdf
# 04/07/17  02:28 AM    <DIR>          course1_downloads
# 04/07/17  02:36 AM            81,573 Coursera Python Intro Class one.ipynb
# 13/07/17  02:00 AM            34,581 Coursera Python Intro Class two.ipynb
# 28/09/16  05:18 PM            17,345 mpg.csv
# 07/07/17  01:12 AM                 0 New Text Document.txt
# 13/07/17  01:34 AM               447 python basic.txt
# 03/07/17  12:00 AM            20,765 Week 2.ipynb
#                7 File(s)        404,734 bytes
#                4 Dir(s)  19,618,816,000 bytes free

# %%
filepath = "course1_downloads/olympics.csv"
df = pd.read_csv(filepath)
df.head()
# Out:
#                    0         1     2     3     4      5         6     7     8  \
# 0                NaN  № Summer  01 !  02 !  03 !  Total  № Winter  01 !  02 !
# 1  Afghanistan (AFG)        13     0     0     2      2         0     0     0
# 2      Algeria (ALG)        12     5     2     8     15         3     0     0
# 3    Argentina (ARG)        23    18    24    28     70        18     0     0
# 4      Armenia (ARM)         5     1     2     9     12         6     0     0
#
#       9     10       11    12    13    14              15
# 0  03 !  Total  № Games  01 !  02 !  03 !  Combined total
# 1     0      0       13     0     0     2               2
# 2     0      0       15     5     2     8              15
# 3     0      0       41    18    24    28              70
# 4     0      0       11     1     2     9              12

# %%
df = pd.read_csv(filepath, index_col=0, skiprows=1)
df.head()
# Out:
#                          № Summer  01 !  02 !  03 !  Total  № Winter  01 !.1  \
# Afghanistan (AFG)              13     0     0     2      2         0       0
# Algeria (ALG)                  12     5     2     8     15         3       0
# Argentina (ARG)                23    18    24    28     70        18       0
# Armenia (ARM)                   5     1     2     9     12         6       0
# Australasia (ANZ) [ANZ]         2     3     4     5     12         0       0
#
#                          02 !.1  03 !.1  Total.1  № Games  01 !.2  02 !.2  \
# Afghanistan (AFG)             0       0        0       13       0       0
# Algeria (ALG)                 0       0        0       15       5       2
# Argentina (ARG)               0       0        0       41      18      24
# Armenia (ARM)                 0       0        0       11       1       2
# Australasia (ANZ) [ANZ]       0       0        0        2       3       4
#
#                          03 !.2  Combined total
# ...

# %%
df.columns
# Out:
# Index(['№ Summer', '01 !', '02 !', '03 !', 'Total', '№ Winter', '01 !.1',
#        '02 !.1', '03 !.1', 'Total.1', '№ Games', '01 !.2', '02 !.2', '03 !.2',
#        'Combined total'],
#       dtype='object')

# %%
for col in df.columns:
    if col[:2]=='01':
        df.rename(columns={col:'Gold' + col[4:]}, inplace=True)
    if col[:2]=='02':
        df.rename(columns={col:'Silver' + col[4:]}, inplace=True)
    if col[:2]=='03':
        df.rename(columns={col:'Bronze' + col[4:]}, inplace=True)
    if col[:1]=='№':
        df.rename(columns={col:'#' + col[1:]}, inplace=True) 

df.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)              13     0       0       2      2         0
# Algeria (ALG)                  12     5       2       8     15         3
# Argentina (ARG)                23    18      24      28     70        18
# Armenia (ARM)                   5     1       2       9     12         6
# Australasia (ANZ) [ANZ]         2     3       4       5     12         0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)             0         0         0        0       13       0
# Algeria (ALG)                 0         0         0        0       15       5
# Argentina (ARG)               0         0         0        0       41      18
# Armenia (ARM)                 0         0         0        0       11       1
# Australasia (ANZ) [ANZ]       0         0         0        0        2       3
#
# ...

# %% [markdown]
# # boolean masking on the array df

# %%
df['Gold'] > 0
# Out:
# Afghanistan (AFG)                               False
# Algeria (ALG)                                    True
# Argentina (ARG)                                  True
# Armenia (ARM)                                    True
# Australasia (ANZ) [ANZ]                          True
# Australia (AUS) [AUS] [Z]                        True
# Austria (AUT)                                    True
# Azerbaijan (AZE)                                 True
# Bahamas (BAH)                                    True
# Bahrain (BRN)                                   False
# Barbados (BAR) [BAR]                            False
# Belarus (BLR)                                    True
# Belgium (BEL)                                    True
# Bermuda (BER)                                   False
# Bohemia (BOH) [BOH] [Z]                         False
# Botswana (BOT)                                  False
# Brazil (BRA)                                     True
# ...

# %%
only_gold = df.where(df['Gold'] > 0)
only_gold.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)             NaN   NaN     NaN     NaN    NaN       NaN
# Algeria (ALG)                12.0   5.0     2.0     8.0   15.0       3.0
# Argentina (ARG)              23.0  18.0    24.0    28.0   70.0      18.0
# Armenia (ARM)                 5.0   1.0     2.0     9.0   12.0       6.0
# Australasia (ANZ) [ANZ]       2.0   3.0     4.0     5.0   12.0       0.0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)           NaN       NaN       NaN      NaN      NaN     NaN
# Algeria (ALG)               0.0       0.0       0.0      0.0     15.0     5.0
# Argentina (ARG)             0.0       0.0       0.0      0.0     41.0    18.0
# Armenia (ARM)               0.0       0.0       0.0      0.0     11.0     1.0
# Australasia (ANZ) [ANZ]     0.0       0.0       0.0      0.0      2.0     3.0
#
# ...

# %%
only_gold['Gold'].count()
# Out:
# 100

# %%
df['Gold'].count()
# Out:
# 147

# %%
only_gold = only_gold.dropna()

# %%
len(df[(df['Gold']>0) | df['Gold.1']>0])
# Out:
# 101

# %%
df[df['Gold.1']>0 & (df['Gold.1']==0)]
# Out:
#                                      # Summer  Gold  Silver  Bronze  Total  \
# Australia (AUS) [AUS] [Z]                  25   139     152     177    468
# Austria (AUT)                              26    18      33      35     86
# Belarus (BLR)                               5    12      24      39     75
# Belgium (BEL)                              25    37      52      53    142
# Bulgaria (BUL) [H]                         19    51      85      78    214
# Canada (CAN)                               25    59      99     121    279
# China (CHN) [CHN]                           9   201     146     126    473
# Croatia (CRO)                               6     6       7      10     23
# Czech Republic (CZE) [CZE]                  5    14      15      15     44
# Czechoslovakia (TCH) [TCH]                 16    49      49      45    143
# Estonia (EST)                              11     9       9      15     33
# ...

# %% [markdown]
# # indexing dataframes

# %%
df.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)              13     0       0       2      2         0
# Algeria (ALG)                  12     5       2       8     15         3
# Argentina (ARG)                23    18      24      28     70        18
# Armenia (ARM)                   5     1       2       9     12         6
# Australasia (ANZ) [ANZ]         2     3       4       5     12         0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)             0         0         0        0       13       0
# Algeria (ALG)                 0         0         0        0       15       5
# Argentina (ARG)               0         0         0        0       41      18
# Armenia (ARM)                 0         0         0        0       11       1
# Australasia (ANZ) [ANZ]       0         0         0        0        2       3
#
# ...

# %%
df['country'] = df.index
df = df.set_index('Gold')
df.head()
# Out:
#       # Summer  Silver  Bronze  Total  # Winter  Gold.1  Silver.1  Bronze.1  \
# Gold
# 0           13       0       2      2         0       0         0         0
# 5           12       2       8     15         3       0         0         0
# 18          23      24      28     70        18       0         0         0
# 1            5       2       9     12         6       0         0         0
# 3            2       4       5     12         0       0         0         0
#
#       Total.1  # Games  Gold.2  Silver.2  Bronze.2  Combined total  \
# Gold
# 0           0       13       0         0         2               2
# 5           0       15       5         2         8              15
# 18          0       41      18        24        28              70
# 1           0       11       1         2         9              12
# 3           0        2       3         4         5              12
#
#                       country
# Gold
# 0           Afghanistan (AFG)
# ...

# %%
df.reset_index()
# Out:
#      Gold  # Summer  Silver  Bronze  Total  # Winter  Gold.1  Silver.1  \
# 0       0        13       0       2      2         0       0         0
# 1       5        12       2       8     15         3       0         0
# 2      18        23      24      28     70        18       0         0
# 3       1         5       2       9     12         6       0         0
# 4       3         2       4       5     12         0       0         0
# 5     139        25     152     177    468        18       5         3
# 6      18        26      33      35     86        22      59        78
# 7       6         5       5      15     26         5       0         0
# 8       5        15       2       5     12         0       0         0
# 9       0         8       0       1      1         0       0         0
# 10      0        11       0       1      1         0       0         0
# 11     12         5      24      39     75         6       6         4
# ...

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is D0E7-419A
#
#  Directory of C:\Users\takchoi\Desktop\MS\Umdearborn\LectureNote\Machine_Learning\Coursera and stanford UFDLD\Python intro
#
# 13/07/17  02:22 AM    <DIR>          .
# 13/07/17  02:22 AM    <DIR>          ..
# 04/07/17  02:33 AM    <DIR>          .ipynb_checkpoints
# 27/06/17  03:38 PM           250,023 class one note.pdf
# 04/07/17  02:28 AM    <DIR>          course1_downloads
# 04/07/17  02:36 AM            81,573 Coursera Python Intro Class one.ipynb
# 13/07/17  02:22 AM           161,670 Coursera Python Intro Class two.ipynb
# 28/09/16  05:18 PM            17,345 mpg.csv
# 07/07/17  01:12 AM                 0 New Text Document.txt
# 13/07/17  01:34 AM               447 python basic.txt
# 03/07/17  12:00 AM            20,765 Week 2.ipynb
#                7 File(s)        531,823 bytes
#                4 Dir(s)  19,623,104,512 bytes free

# %%
df = pd.read_csv('course1_downloads/census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
df['SUMLEV'].unique()
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
columns_to_keep = ['STNAME',
                   'CTYNAME',
                   'BIRTHS2010',
                   'BIRTHS2011',
                   'BIRTHS2012',
                   'BIRTHS2013',
                   'BIRTHS2014',
                   'BIRTHS2015',
                   'POPESTIMATE2010',
                   'POPESTIMATE2011',
                   'POPESTIMATE2012',
                   'POPESTIMATE2013',
                   'POPESTIMATE2014',
                   'POPESTIMATE2015']
df = df[columns_to_keep]
df.head()
# Out:
#     STNAME         CTYNAME  BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# 0  Alabama         Alabama       14226       59689       59062       57938
# 1  Alabama  Autauga County         151         636         615         574
# 2  Alabama  Baldwin County         517        2187        2092        2160
# 3  Alabama  Barbour County          70         335         300         283
# 4  Alabama     Bibb County          44         266         245         259
#
#    BIRTHS2014  BIRTHS2015  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# 0       58334       58305          4785161          4801108          4816089
# 1         623         600            54660            55253            55175
# 2        2186        2240           183193           186659           190396
# 3         260         269            27341            27226            27159
# 4         247         253            22861            22733            22642
#
# ...

# %%
df = df.set_index(['STNAME','CTYNAME'])
df.head()
# Out:
#                         BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME  CTYNAME
# Alabama Alabama              14226       59689       59062       57938
#         Autauga County         151         636         615         574
#         Baldwin County         517        2187        2092        2160
#         Barbour County          70         335         300         283
#         Bibb County             44         266         245         259
#
#                         BIRTHS2014  BIRTHS2015  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Alabama              58334       58305          4785161
#         Autauga County         623         600            54660
#         Baldwin County        2186        2240           183193
#         Barbour County         260         269            27341
#         Bibb County            247         253            22861
#
#                         POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# STNAME  CTYNAME
# ...

# %%
df.loc['Michigan','Washtenaw County']
# Out:
# C:\Users\takchoi\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if __name__ == '__main__':
#                            BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME   CTYNAME
# Michigan Washtenaw County         977        3826        3780        3662
#
#                            BIRTHS2014  BIRTHS2015  POPESTIMATE2010  \
# STNAME   CTYNAME
# Michigan Washtenaw County        3683        3709           345563
#
#                            POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# STNAME   CTYNAME
# Michigan Washtenaw County           349048           351213           354289
#
#                            POPESTIMATE2014  POPESTIMATE2015
# STNAME   CTYNAME
# Michigan Washtenaw County           357029           358880

# %%
df.loc[ [('Michigan','Washtenaw County'),('Michigan','Wayne County')]]
# Out:
#                            BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME   CTYNAME
# Michigan Washtenaw County         977        3826        3780        3662
#          Wayne County            5918       23819       23270       23377
#
#                            BIRTHS2014  BIRTHS2015  POPESTIMATE2010  \
# STNAME   CTYNAME
# Michigan Washtenaw County        3683        3709           345563
#          Wayne County           23607       23586          1815199
#
#                            POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# STNAME   CTYNAME
# Michigan Washtenaw County           349048           351213           354289
#          Wayne County              1801273          1792514          1775713
#
#                            POPESTIMATE2014  POPESTIMATE2015
# STNAME   CTYNAME
# Michigan Washtenaw County           357029           358880
#          Wayne County              1766008          1759335

# %%
# exercise

# %%
purchase_1 = pd.Series({'Name': 'Chris',
                        'Item Purchased': 'Dog Food',
                        'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost': 2.50})
purchase_3 = pd.Series({'Name': 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost': 5.00})

df = pd.DataFrame([purchase_1, purchase_2, purchase_3], index=['Store 1', 'Store 1', 'Store 2'])


# Your answer here
df = df.set_index([df.index,'Name'])
df.index.names = ['Location','Name']                  
df = df.append(pd.Series(data={'Cost': 3.00,
                               'Item Purchased': 'Kitty Food'}, name=('Store 2', 'Kevyn')))
print(df)
# Out:
#                 Cost Item Purchased
# Location Name
# Store 1  Chris  22.5       Dog Food
#          Kevyn   2.5   Kitty Litter
# Store 2  Vinod   5.0      Bird Seed
#          Kevyn   3.0     Kitty Food

# %%
df = pd.read_csv('course1_downloads/log.csv')
df
# Out:
#           time    user          video  playback position paused  volume
# 0   1469974424  cheryl     intro.html                  5  False    10.0
# 1   1469974454  cheryl     intro.html                  6    NaN     NaN
# 2   1469974544  cheryl     intro.html                  9    NaN     NaN
# 3   1469974574  cheryl     intro.html                 10    NaN     NaN
# 4   1469977514     bob     intro.html                  1    NaN     NaN
# 5   1469977544     bob     intro.html                  1    NaN     NaN
# 6   1469977574     bob     intro.html                  1    NaN     NaN
# 7   1469977604     bob     intro.html                  1    NaN     NaN
# 8   1469974604  cheryl     intro.html                 11    NaN     NaN
# 9   1469974694  cheryl     intro.html                 14    NaN     NaN
# 10  1469974724  cheryl     intro.html                 15    NaN     NaN
# 11  1469974454     sue  advanced.html                 24    NaN     NaN
# ...

# %%
df.fillna?

# %%
df = df.set_index('time')
df = df.sort_index()

# %%
df
df = df.reset_index()
df  = df.set_index(['time','user'])
df
# Out:
#                            video  playback position paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5  False    10.0
#            sue     advanced.html                 23  False    10.0
# 1469974454 cheryl     intro.html                  6    NaN     NaN
#            sue     advanced.html                 24    NaN     NaN
# 1469974484 cheryl     intro.html                  7    NaN     NaN
# 1469974514 cheryl     intro.html                  8    NaN     NaN
# 1469974524 sue     advanced.html                 25    NaN     NaN
# 1469974544 cheryl     intro.html                  9    NaN     NaN
# 1469974554 sue     advanced.html                 26    NaN     NaN
# 1469974574 cheryl     intro.html                 10    NaN     NaN
# 1469974604 cheryl     intro.html                 11    NaN     NaN
# 1469974624 sue     advanced.html                 27    NaN     NaN
# 1469974634 cheryl     intro.html                 12    NaN     NaN
# ...

# %%
df.fillna(1)
# Out:
#                            video  playback position paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5  False    10.0
#            sue     advanced.html                 23  False    10.0
# 1469974454 cheryl     intro.html                  6      1     1.0
#            sue     advanced.html                 24      1     1.0
# 1469974484 cheryl     intro.html                  7      1     1.0
# 1469974514 cheryl     intro.html                  8      1     1.0
# 1469974524 sue     advanced.html                 25      1     1.0
# 1469974544 cheryl     intro.html                  9      1     1.0
# 1469974554 sue     advanced.html                 26      1     1.0
# 1469974574 cheryl     intro.html                 10      1     1.0
# 1469974604 cheryl     intro.html                 11      1     1.0
# 1469974624 sue     advanced.html                 27      1     1.0
# 1469974634 cheryl     intro.html                 12      1     1.0
# ...
